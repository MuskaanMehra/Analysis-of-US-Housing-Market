# %%
# Importing necessary libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("ProjectData.csv")

# %%
cd
# Out:
# C:\Users\muska

# %%
cd\Users\muska\OneDrive\Desktop
# Out:
# C:\Users\muska\OneDrive\Desktop

# %%
data=pd.read_csv("projectData.csv")

# %%
data.shape
# Out:
# (280, 12)

# %%
data.head(10)
# Out:
#        HPI  UNEMP       CPI   DFF        GDP  PERMIT  Housing Inventory  \
# 0  100.551    4.0  3.376857  3.99  10002.179  1727.0            11000.0
# 1  101.339    4.1  3.376857  5.79  10002.179  1692.0            11000.0
# 2  102.126    4.0  3.376857  5.78  10002.179  1651.0            11000.0
# 3  102.922    3.8  3.376857  6.17  10247.720  1597.0           116047.0
# 4  103.677    4.0  3.376857  6.17  10247.720  1543.0           116047.0
# 5  104.424    4.0  3.376857  6.65  10247.720  1572.0           116047.0
# 6  105.053    4.0  3.376857  6.86  10318.165  1542.0           116482.0
# 7  105.768    4.1  3.376857  6.51  10318.165  1552.0           116482.0
# 8  106.538    3.9  3.376857  6.52  10318.165  1570.0           116482.0
# 9  107.382    3.9  3.376857  6.60  10435.744  1577.0           116914.0
#
#    Med Household Income  Working Population  PPI-Construction  Mortgage  \
# 0               41990.0         178291813.5             144.1      8.26
# 1               41990.0         178341125.8             144.7      8.26
# 2               41990.0         178401779.6             145.4      8.26
# 3               41990.0         178581196.5             145.6      8.32
# 4               41990.0         178727641.3             144.9      8.32
# 5               41990.0         179056626.2             145.0      8.32
# 6               41990.0         179327691.3             144.4      8.02
# 7               41990.0         179397067.0             143.7      8.02
# 8               41990.0         179568086.1             143.4      8.02
# 9               41990.0         179755338.5             143.3      7.62
#
#    MONTH  YEAR
# 0      1  2000
# 1      1  2000
# 2      1  2000
# 3      1  2000
# 4      1  2000
# 5      1  2000
# 6      1  2000
# 7      1  2000
# 8      1  2000
# 9      1  2000

# %%
data=data.ffill(axis=0)

# %%
data.head()
# Out:
#          DATE      HPI  UNEMP       CPI   DFF        GDP  PERMIT  \
# 0  2000-01-01  100.551    4.0  3.376857  3.99  10002.179  1727.0
# 1  2000-02-01  101.339    4.1  3.376857  5.79  10002.179  1692.0
# 2  2000-03-01  102.126    4.0  3.376857  5.78  10002.179  1651.0
# 3  2000-04-01  102.922    3.8  3.376857  6.17  10247.720  1597.0
# 4  2000-05-01  103.677    4.0  3.376857  6.17  10247.720  1543.0
#
#    Housing Inventory  Med Household Income  Working Population  \
# 0                NaN               41990.0         178291813.5
# 1                NaN               41990.0         178341125.8
# 2                NaN               41990.0         178401779.6
# 3           116047.0               41990.0         178581196.5
# 4           116047.0               41990.0         178727641.3
#
#    PPI-Construction  Mortgage
# 0             144.1      8.26
# 1             144.7      8.26
# 2             145.4      8.26
# 3             145.6      8.32
# 4             144.9      8.32

# %%
data=data.fillna(11000)

# %%
data.head()
# Out:
#          DATE      HPI  UNEMP       CPI   DFF        GDP  PERMIT  \
# 0  2000-01-01  100.551    4.0  3.376857  3.99  10002.179  1727.0
# 1  2000-02-01  101.339    4.1  3.376857  5.79  10002.179  1692.0
# 2  2000-03-01  102.126    4.0  3.376857  5.78  10002.179  1651.0
# 3  2000-04-01  102.922    3.8  3.376857  6.17  10247.720  1597.0
# 4  2000-05-01  103.677    4.0  3.376857  6.17  10247.720  1543.0
#
#    Housing Inventory  Med Household Income  Working Population  \
# 0            11000.0               41990.0         178291813.5
# 1            11000.0               41990.0         178341125.8
# 2            11000.0               41990.0         178401779.6
# 3           116047.0               41990.0         178581196.5
# 4           116047.0               41990.0         178727641.3
#
#    PPI-Construction  Mortgage
# 0             144.1      8.26
# 1             144.7      8.26
# 2             145.4      8.26
# 3             145.6      8.32
# 4             144.9      8.32

# %% [markdown]
# # Exploratory Data Analysis

# %%
data.describe().T.round()
# Out:
#                       count         mean        std          min          25%  \
# HPI                   280.0        174.0       47.0        101.0        142.0
# UNEMP                 280.0          6.0        2.0          3.0          4.0
# CPI                   280.0          3.0        2.0         -0.0          2.0
# DFF                   280.0          2.0        2.0          0.0          0.0
# GDP                   280.0      16468.0     4266.0      10002.0      13324.0
# PERMIT                280.0       1355.0      460.0        513.0       1017.0
# Housing Inventory     280.0     130357.0    14535.0      11000.0     126104.0
# Med Household Income  280.0      53934.0     9382.0      41990.0      46326.0
# Working Population    280.0  197863653.0  8596123.0  178291814.0  191863004.0
# PPI-Construction      280.0        206.0       50.0        142.0        172.0
# Mortgage              280.0          5.0        1.0          3.0          4.0
#
#                               50%          75%          max
# HPI                         167.0        191.0        305.0
# UNEMP                         5.0          7.0         15.0
# CPI                           2.0          3.0          8.0
# DFF                           1.0          2.0          7.0
# GDP                       15648.0      19369.0      26466.0
# PERMIT                     1339.0       1693.0       2263.0
# Housing Inventory        132362.0     137151.0     144287.0
# Med Household Income      50303.0      61136.0      70784.0
# Working Population    200190609.0  205378490.0  208305758.0
# PPI-Construction            203.0        222.0        353.0
# Mortgage                      5.0          6.0          8.0

# %%
data.isnull().sum()
# Out:
# DATE                    0
# HPI                     0
# UNEMP                   0
# CPI                     0
# DFF                     0
# GDP                     0
# PERMIT                  0
# Housing Inventory       0
# Med Household Income    0
# Working Population      0
# PPI-Construction        0
# Mortgage                0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   DATE                  280 non-null    object
#  1   HPI                   280 non-null    float64
#  2   UNEMP                 280 non-null    float64
#  3   CPI                   280 non-null    float64
#  4   DFF                   280 non-null    float64
#  5   GDP                   280 non-null    float64
#  6   PERMIT                280 non-null    float64
#  7   Housing Inventory     280 non-null    float64
#  8   Med Household Income  280 non-null    float64
#  9   Working Population    280 non-null    float64
#  10  PPI-Construction      280 non-null    float64
#  11  Mortgage              280 non-null    float64
# dtypes: float64(11), object(1)
# memory usage: 26.4+ KB

# %%
# Converting date feature to Datetime
data['DATE']=pd.to_datetime(data['DATE'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   DATE                  280 non-null    datetime64[ns]
#  1   HPI                   280 non-null    float64
#  2   UNEMP                 280 non-null    float64
#  3   CPI                   280 non-null    float64
#  4   DFF                   280 non-null    float64
#  5   GDP                   280 non-null    float64
#  6   PERMIT                280 non-null    float64
#  7   Housing Inventory     280 non-null    float64
#  8   Med Household Income  280 non-null    float64
#  9   Working Population    280 non-null    float64
#  10  PPI-Construction      280 non-null    float64
#  11  Mortgage              280 non-null    float64
# dtypes: datetime64[ns](1), float64(11)
# memory usage: 26.4 KB

# %%
data1=data.drop(['DATE','HPI'],axis=1)

# %%
data1.head()
# Out:
#    UNEMP       CPI   DFF        GDP  PERMIT  Housing Inventory  \
# 0    4.0  3.376857  3.99  10002.179  1727.0            11000.0
# 1    4.1  3.376857  5.79  10002.179  1692.0            11000.0
# 2    4.0  3.376857  5.78  10002.179  1651.0            11000.0
# 3    3.8  3.376857  6.17  10247.720  1597.0           116047.0
# 4    4.0  3.376857  6.17  10247.720  1543.0           116047.0
#
#    Med Household Income  Working Population  PPI-Construction  Mortgage
# 0               41990.0         178291813.5             144.1      8.26
# 1               41990.0         178341125.8             144.7      8.26
# 2               41990.0         178401779.6             145.4      8.26
# 3               41990.0         178581196.5             145.6      8.32
# 4               41990.0         178727641.3             144.9      8.32

# %% [markdown]
#  Distribution Histogram

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
columns=data1.columns
k=1
plt.figure(figsize=(25,20))
for i in columns:
    plt.subplot(4,4,k)
    sns.distplot(data1[i])
    k+=1

# %%
k=1
plt.figure(figsize=(25,20))
for i in columns:
    plt.subplot(4,4,k)
    sns.boxplot(data1[i])
    k+=1

# %% [markdown]
# Scatter Plot

# %%
columns=data.columns
k=1
plt.figure(figsize=(25,20))
for i in columns:
    plt.subplot(4,4,k)
    sns.scatterplot(x=data[i], y=data['HPI'])
    k+=1

# %% [markdown]
# HPI Distribution

# %%
sns.histplot(data=data, x=data.HPI, kde=True)
plt.title('Distribution of HPI')
plt.show()

# %% [markdown]
# # Correlation of Data

# %%
plt.figure(figsize=(8, 8))
sns.heatmap(data1.corr(),cmap='viridis', annot = True)
plt.title("Correlation between Variables")
plt.show()

# %%
data['MONTH']=data['DATE'].dt.day
data['YEAR']=data['DATE'].dt.year
data=data.drop(['DATE'],axis=1)

# %%
data.columns
# Out:
# Index(['HPI', 'UNEMP', 'CPI', 'DFF', 'GDP', 'PERMIT', 'Housing Inventory',
#        'Med Household Income', 'Working Population', 'PPI-Construction',
#        'Mortgage', 'MONTH', 'YEAR'],
#       dtype='object')

# %%
X= data.drop(['HPI'], axis='columns')
y=data['HPI']

# %%
X.head()
# Out:
#    UNEMP       CPI   DFF        GDP  PERMIT  Housing Inventory  \
# 0    4.0  3.376857  3.99  10002.179  1727.0            11000.0
# 1    4.1  3.376857  5.79  10002.179  1692.0            11000.0
# 2    4.0  3.376857  5.78  10002.179  1651.0            11000.0
# 3    3.8  3.376857  6.17  10247.720  1597.0           116047.0
# 4    4.0  3.376857  6.17  10247.720  1543.0           116047.0
#
#    Med Household Income  Working Population  PPI-Construction  Mortgage  \
# 0               41990.0         178291813.5             144.1      8.26
# 1               41990.0         178341125.8             144.7      8.26
# 2               41990.0         178401779.6             145.4      8.26
# 3               41990.0         178581196.5             145.6      8.32
# 4               41990.0         178727641.3             144.9      8.32
#
#    MONTH  YEAR
# 0      1  2000
# 1      1  2000
# 2      1  2000
# 3      1  2000
# 4      1  2000

# %%
y.head()
# Out:
# 0    100.551
# 1    101.339
# 2    102.126
# 3    102.922
# 4    103.677
# Name: HPI, dtype: float64

# %% [markdown]
# Splitting data into training and test set

# %%
import sklearn
from sklearn.model_selection import train_test_split

X_train,X_test, y_train, y_test=train_test_split(X,y,test_size=0.2,random_state=100)

# %% [markdown]
# # Feature Selection

# %%
from sklearn.ensemble import ExtraTreesRegressor
selection = ExtraTreesRegressor()
selection.fit(X, y)
# Out:
# ExtraTreesRegressor()

# %%
print(selection.feature_importances_)
# Out:
# [0.03431917 0.03827413 0.01455415 0.1583422  0.00926522 0.07090575
#  0.21194054 0.05087515 0.23583472 0.04780658 0.         0.12788239]

# %%
plt.figure(figsize = (8,8))
feat_importances = pd.Series(selection.feature_importances_, index=X.columns)
feat_importances.nlargest(20).plot(kind='barh')
plt.show()

# %% [markdown]
# # Multiple Linear Regression

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test, y_test)
# Out:
# 0.982444207011124

# %%
from sklearn.metrics import r2_score

y_predicted=model.predict(X_test)

r2_score(y_test, y_predicted)
# Out:
# 0.982444207011124

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mse=mean_squared_error(y_test,y_predicted)
mae=mean_absolute_error(y_test,y_predicted)

# %%
print('MSE: ',mse)
print('MAE: ',mae)
# Out:
# MSE:  41.93022437097951
# MAE:  5.307015117081442

# %%
y_predicted
# Out:
# array([160.30938013, 211.6304073 , 177.94264625, 182.46664472,
#        217.33697774, 162.22450575, 217.95805977, 154.1020105 ,
#        178.03853061, 225.86489093, 285.30679888, 295.51740525,
#        160.73070032, 159.76236089, 174.07074697, 172.28833844,
#        235.48804766, 180.90376029, 161.78117095, 207.39574287,
#        145.46323527, 128.4889983 , 211.27495185, 168.48543078,
#        296.19018979, 136.4273439 , 149.11286701, 288.16351362,
#        173.08056523, 101.304362  , 119.98402462, 206.37785336,
#        160.21847342, 193.59102906, 155.25410292, 184.1423744 ,
#        294.57390967, 173.89747403, 141.8641721 , 133.5538477 ,
#        221.1222499 , 125.63123317, 155.15813624, 123.54556247,
#        218.17635681, 170.13328414, 187.23995724, 143.84901747,
#        137.34502804, 141.75352343, 114.37541111, 281.75863339,
#        268.00964909, 148.8496903 , 165.2061648 , 118.47418679])

# %%
model.coef_
# Out:
# array([ 3.42383770e+00, -2.63499701e-01,  1.02085258e+00,  1.05287546e-02,
#         3.52391650e-02,  1.14367381e-04,  3.24513717e-03,  4.13782658e-06,
#         5.24817430e-01,  4.58818251e+00,  0.00000000e+00, -1.21069978e+01])

# %%
X.columns
# Out:
# Index(['UNEMP', 'CPI', 'DFF', 'GDP', 'PERMIT', 'Housing Inventory',
#        'Med Household Income', 'Working Population', 'PPI-Construction',
#        'Mortgage', 'MONTH', 'YEAR'],
#       dtype='object')

# %%
model.intercept_
# Out:
# 23142.000660626825

# %%
plt.scatter(y_test, y_predicted, alpha = 0.5)
plt.xlabel("y_test")
plt.ylabel("y_predicted")
plt.show()

# %%
sns.distplot(y_test-y_predicted)
plt.show()

# %%
import statsmodels.api as sm

# %%
X_train= sm.add_constant(X_train)

# %%
model1 = sm.OLS(y_train, X_train).fit()

# %%
print(model1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    HPI   R-squared:                       0.980
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     935.9
# Date:                Wed, 17 May 2023   Prob (F-statistic):          5.24e-173
# Time:                        19:55:09   Log-Likelihood:                -738.18
# No. Observations:                 224   AIC:                             1500.
# Df Residuals:                     212   BIC:                             1541.
# Df Model:                          11
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# UNEMP                    3.4238      0.527      6.500      0.000       2.385       4.462
# CPI                     -0.2635      0.606     -0.435      0.664      -1.458       0.931
# DFF                      1.0209      0.545      1.873      0.062      -0.053       2.095
# GDP                      0.0105      0.002      5.743      0.000       0.007       0.014
# PERMIT                   0.0352      0.002     19.540      0.000       0.032       0.039
# Housing Inventory        0.0001   4.85e-05      2.359      0.019    1.88e-05       0.000
# Med Household Income     0.0032      0.000      7.962      0.000       0.002       0.004
# Working Population    4.138e-06   2.66e-07     15.567      0.000    3.61e-06    4.66e-06
# PPI-Construction         0.5248      0.063      8.305      0.000       0.400       0.649
# Mortgage                 4.5882      1.464      3.134      0.002       1.703       7.474
# MONTH                 2.314e+04   2081.535     11.118      0.000     1.9e+04    2.72e+04
# YEAR                   -12.1070      1.058    -11.438      0.000     -14.194     -10.020
# ==============================================================================
# Omnibus:                        2.346   Durbin-Watson:                   1.845
# Prob(Omnibus):                  0.309   Jarque-Bera (JB):                1.879
# Skew:                           0.070   Prob(JB):                        0.391
# Kurtosis:                       2.574   Cond. No.                     9.17e+11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.17e+11. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Decision Tree

# %%
from sklearn import tree

# %%
model=tree.DecisionTreeRegressor()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
model.score(X_test, y_test)
# Out:
# 0.996028708509679

# %%
y_pred=model.predict(X_test)

r2_score(y_test, y_predicted)
# Out:
# 0.982444207011124

# %%
mse=mean_squared_error(y_test,y_predicted)
mae=mean_absolute_error(y_test,y_predicted)

# %%
print('MSE: ',mse)
print('MAE: ',mae)
# Out:
# MSE:  41.93022437097951
# MAE:  5.307015117081442

# %%
sns.distplot(y_test-y_predicted)
plt.show()

# %%
plt.scatter(y_test, y_pred, alpha = 0.5)
plt.xlabel("y_test")
plt.ylabel("y_predicted")
plt.show()

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
reg_rf = RandomForestRegressor()
reg_rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = reg_rf.predict(X_test)

# %%
reg_rf.score(X_train, y_train)
# Out:
# 0.9997718247315546

# %%
mse=mean_squared_error(y_test,y_predicted)
mae=mean_absolute_error(y_test,y_predicted)

# %%
print('MSE: ',mse)
print('MAE: ',mae)
# Out:
# MSE:  41.93022437097951
# MAE:  5.307015117081442

# %%
plt.scatter(y_test, y_pred, alpha = 0.5)
plt.xlabel("y_test")
plt.ylabel("y_predicted")
plt.show()

# %%
sns.distplot(y_test-y_predicted)
plt.show()
